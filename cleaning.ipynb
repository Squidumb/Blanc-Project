# %%
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# %%
fiscal_df=pd.read_csv("data/raw_data.csv")
gpd_df=pd.read_csv("data/total-confirmed-cases-of-covid-19-per-million-people-vs-gdp-per-capita.csv")

# %%
columns_to_drop = ['Code', 'Total confirmed cases of COVID-19 per million people', 'year']

# Create a new DataFrame with selected columns dropped
gdp_cleaned = gpd_df.drop(columns=columns_to_drop, )
gdp_cleaned = gdp_cleaned.rename(columns={'Entity': 'country'})
# Save the cleaned dataset to a new CSV file
gdp_cleaned.to_csv('gdp_cleaned.csv', index=False)

# %%
columns_to_drop = ['geoid', 'iso', 'id', 'sectorial', 'inkind', 'creditin', 'offbudget', 'policyrate', 'cash']

# Create a new DataFrame with selected columns dropped
fiscal_cleaned = fiscal_df.drop(columns=columns_to_drop)

# Save the cleaned dataset to a new CSV file
fiscal_cleaned.to_csv('fiscal_cleaned.csv', index=False)

# %%
gdp_data = pd.read_csv('gdp_cleaned.csv')
fiscal_data = pd.read_csv('fiscal_cleaned.csv')

# Filter the data for the specified countries
countries_to_include = ['China', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom', 'United States', 'South Korea', 'Spain']

gdp_data = gdp_data[gdp_data['country'].isin(countries_to_include)]
fiscal_data = fiscal_data[fiscal_data['country'].isin(countries_to_include)]

# Initialize the Dash app
app = dash.Dash(__name__)

# Create a dark theme layout
app.layout = html.Div([
    html.H1("Scatter Plot of GDP vs Fiscal Data", style={'color': 'white'}),
    dcc.Graph(id='scatter-plot', config={'displayModeBar': False}),
])

@app.callback(
    Output('scatter-plot', 'figure'),
    [Input('scatter-plot', 'relayoutData')]
)
def update_scatter_plot(relayoutData):
    # Merge the two datasets if necessary
    merged_data = pd.merge(gdp_data, fiscal_data, on='country')

    # Create the scatter plot using Plotly Express
    fig = px.scatter(merged_data, x='GDP per capita, PPP (constant 2017 international $)', y='total_fiscal', color='Country', title="GDP vs Fiscal Data")

    # Set a dark theme template
    fig.update_layout(template='plotly_dark')

    return fig

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotly/express/_chart_types.py:66, in scatter(
#     data_frame=                country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns],
#     x='GDP per capita, PPP (constant 2017 international $)',
#     y='total_fiscal',
#     color='Country',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='auto',
#     title='GDP vs Fiscal Data',
#     template=None,
#     width=None,
#     height=None
# )
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         go = <module 'plotly.graph_objs' from '/home/saikowsik/.local/lib/python3.10/site-packages/plotly/graph_objs/__init__.py'>
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:2076, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1485, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1210, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#         err_msg = "Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['country', 'Day', 'Continent', 'GDP per capita, PPP (constant 2017 international $)', 'Year', 'Unnamed: 0', 'd', 'date', 'fiscal', 'taxd', 'taxc', 'wage', 'continent', 'total_fiscal', 'total_wage', 'total_cash', 'total_inkind', 'total_taxc', 'total_creditin', 'total_sectorial', 'total_taxd', 'total_offbudget'] but received: Country"
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['country', 'Day', 'Continent', 'GDP per capita, PPP (constant 2017 international $)', 'Year', 'Unnamed: 0', 'd', 'date', 'fiscal', 'taxd', 'taxc', 'wage', 'continent', 'total_fiscal', 'total_wage', 'total_cash', 'total_inkind', 'total_taxc', 'total_creditin', 'total_sectorial', 'total_taxd', 'total_offbudget'] but received: Country
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotly/express/_chart_types.py:66, in scatter(
#     data_frame=                country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns],
#     x='GDP per capita, PPP (constant 2017 international $)',
#     y='total_fiscal',
#     color='Country',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='auto',
#     title='GDP vs Fiscal Data',
#     template=None,
#     width=None,
#     height=None
# )
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         go = <module 'plotly.graph_objs' from '/home/saikowsik/.local/lib/python3.10/site-packages/plotly/graph_objs/__init__.py'>
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:2076, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1485, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1210, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#         err_msg = "Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['country', 'Day', 'Continent', 'GDP per capita, PPP (constant 2017 international $)', 'Year', 'Unnamed: 0', 'd', 'date', 'fiscal', 'taxd', 'taxc', 'wage', 'continent', 'total_fiscal', 'total_wage', 'total_cash', 'total_inkind', 'total_taxc', 'total_creditin', 'total_sectorial', 'total_taxd', 'total_offbudget'] but received: Country"
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['country', 'Day', 'Continent', 'GDP per capita, PPP (constant 2017 international $)', 'Year', 'Unnamed: 0', 'd', 'date', 'fiscal', 'taxd', 'taxc', 'wage', 'continent', 'total_fiscal', 'total_wage', 'total_cash', 'total_inkind', 'total_taxc', 'total_creditin', 'total_sectorial', 'total_taxd', 'total_offbudget'] but received: Country
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotly/express/_chart_types.py:66, in scatter(
#     data_frame=                country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns],
#     x='GDP per capita, PPP (constant 2017 international $)',
#     y='total_fiscal',
#     color='Country',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='auto',
#     title='GDP vs Fiscal Data',
#     template=None,
#     width=None,
#     height=None
# )
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         go = <module 'plotly.graph_objs' from '/home/saikowsik/.local/lib/python3.10/site-packages/plotly/graph_objs/__init__.py'>
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:2076, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1485, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1210, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# ...
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='auto',
#     title='GDP vs Fiscal Data',
#     template=None,
#     width=None,
#     height=None
# )
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         go = <module 'plotly.graph_objs' from '/home/saikowsik/.local/lib/python3.10/site-packages/plotly/graph_objs/__init__.py'>
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:2076, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2073 layout_patch = layout_patch or {}
#    2074 apply_default_cascade(args)
# -> 2076 args = build_dataframe(args, constructor)
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    2077 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2078     args = process_dataframe_hierarchy(args)
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1485, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1482     args["color"] = None
#    1483 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1485 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':                 country         Day Continent  \
# 0                 China  2020-01-04      Asia
# 1                 China  2020-01-04      Asia
# 2                 China  2020-01-04      Asia
# 3                 China  2020-01-04      Asia
# 4                 China  2020-01-04      Asia
# ...                 ...         ...       ...
# 4965543  United Kingdom  2023-10-18    Europe
# 4965544  United Kingdom  2023-10-18    Europe
# 4965545  United Kingdom  2023-10-18    Europe
# 4965546  United Kingdom  2023-10-18    Europe
# 4965547  United Kingdom  2023-10-18    Europe
#
#          GDP per capita, PPP (constant 2017 international $)    Year  \
# 0                                                16315.815    2020.0
# 1                                                16315.815    2020.0
# 2                                                16315.815    2020.0
# 3                                                16315.815    2020.0
# 4                                                16315.815    2020.0
# ...                                                    ...       ...
# 4965543                                          42675.780    2020.0
# 4965544                                          42675.780    2020.0
# 4965545                                          42675.780    2020.0
# 4965546                                          42675.780    2020.0
# 4965547                                          42675.780    2020.0
#
#          Unnamed: 0           d        date  fiscal  taxd  ...  continent  \
# 0             16058  2020-01-01  01/01/2020     0.0   0.0  ...       Asia
# 1             16059  2020-01-02  02/01/2020     0.0   0.0  ...       Asia
# 2             16060  2020-01-03  03/01/2020     0.0   0.0  ...       Asia
# 3             16061  2020-01-04  04/01/2020     0.0   0.0  ...       Asia
# 4             16062  2020-01-05  05/01/2020     0.0   0.0  ...       Asia
# ...             ...         ...         ...     ...   ...  ...        ...
# 4965543       91681  2021-05-28  28/05/2021     0.0   0.0  ...     Europe
# 4965544       91682  2021-05-29  29/05/2021     0.0   0.0  ...     Europe
# 4965545       91683  2021-05-30  30/05/2021     0.0   0.0  ...     Europe
# 4965546       91684  2021-05-31  31/05/2021     0.0   0.0  ...     Europe
# 4965547       91685  2021-06-01  01/06/2021     0.0   0.0  ...     Europe
#
#          total_fiscal total_wage  total_cash  total_inkind  total_taxc  \
# 0                4.83       0.02        0.15           0.0       2.670
# 1                4.83       0.02        0.15           0.0       2.670
# 2                4.83       0.02        0.15           0.0       2.670
# 3                4.83       0.02        0.15           0.0       2.670
# 4                4.83       0.02        0.15           0.0       2.670
# ...               ...        ...         ...           ...         ...
# 4965543         16.02       3.92        0.67           0.0       0.798
# 4965544         16.02       3.92        0.67           0.0       0.798
# 4965545         16.02       3.92        0.67           0.0       0.798
# 4965546         16.02       3.92        0.67           0.0       0.798
# 4965547         16.02       3.92        0.67           0.0       0.798
#
#          total_creditin  total_sectorial  total_taxd  total_offbudget
# 0                  0.00             0.15        1.57             1.71
# 1                  0.00             0.15        1.57             1.71
# 2                  0.00             0.15        1.57             1.71
# 3                  0.00             0.15        1.57             1.71
# 4                  0.00             0.15        1.57             1.71
# ...                 ...              ...         ...              ...
# 4965543            0.26             2.32        1.32             0.00
# 4965544            0.26             2.32        1.32             0.00
# 4965545            0.26             2.32        1.32             0.00
# 4965546            0.26             2.32        1.32             0.00
# 4965547            0.26             2.32        1.32             0.00
#
# [4965548 rows x 22 columns], 'x': 'GDP per capita, PPP (constant 2017 international $)', 'y': 'total_fiscal', 'color': 'Country', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'GDP vs Fiscal Data', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1486     args, wide_mode, var_name, value_name
#    1487 )
#    1489 # now that `df_output` exists and `args` contains only references, we complete
#    1490 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1491 # df_output
#    1493 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/.local/lib/python3.10/site-packages/plotly/express/_core.py:1210, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Country', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':                 country         Day Continent  \...2             0.00
#
# [4965548 rows x 22 columns], ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1208         if argument == "index":
#    1209             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1210         raise ValueError(err_msg)
#         err_msg = "Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['country', 'Day', 'Continent', 'GDP per capita, PPP (constant 2017 international $)', 'Year', 'Unnamed: 0', 'd', 'date', 'fiscal', 'taxd', 'taxc', 'wage', 'continent', 'total_fiscal', 'total_wage', 'total_cash', 'total_inkind', 'total_taxc', 'total_creditin', 'total_sectorial', 'total_taxd', 'total_offbudget'] but received: Country"
#    1211 elif length and len(df_input[argument]) != length:
#    1212     raise ValueError(
#    1213         "All arguments should have the same length. "
#    1214         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1221         )
#    1222     )
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['country', 'Day', 'Continent', 'GDP per capita, PPP (constant 2017 international $)', 'Year', 'Unnamed: 0', 'd', 'date', 'fiscal', 'taxd', 'taxc', 'wage', 'continent', 'total_fiscal', 'total_wage', 'total_cash', 'total_inkind', 'total_taxc', 'total_creditin', 'total_sectorial', 'total_taxd', 'total_offbudget'] but received: Country
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
